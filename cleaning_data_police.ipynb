# %%
import pandas as pd

# %%
data = pd.DataFrame()
citytokent = pd.read_csv("citytokent.csv")
hamptolanca = pd.read_csv("hamptolanca.csv")
frommereyside = pd.read_csv("frommereyside.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (5,7,9,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data = data.append(citytokent, ignore_index = True)
data = data.append(hamptolanca, ignore_index = True)
data = data.append(frommereyside, ignore_index = True)

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'age_range',
#  'outcome',
#  'involved_person',
#  'self_defined_ethnicity',
#  'gender',
#  'legislation',
#  'outcome_linked_to_object_of_search',
#  'datetime',
#  'removal_of_more_than_outer_clothing',
#  'outcome_object',
#  'location',
#  'operation',
#  'officer_defined_ethnicity',
#  'type',
#  'operation_name',
#  'object_of_search',
#  'force']

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data.isna().sum()
# Out:
# age_range                               233665
# outcome                                  54943
# involved_person                              0
# self_defined_ethnicity                  180126
# gender                                  386730
# legislation                             226488
# outcome_linked_to_object_of_search     1622210
# datetime                                     0
# removal_of_more_than_outer_clothing     777154
# outcome_object                               0
# location                                824862
# operation                              1719010
# officer_defined_ethnicity               391935
# type                                         0
# operation_name                         2893385
# object_of_search                        407541
# force                                        0
# dtype: int64

# %%
data = data.drop(["operation_name"], axis=1)

# %%
data.isna().sum()
# Out:
# age_range                               233665
# outcome                                  54943
# involved_person                              0
# self_defined_ethnicity                  180126
# gender                                  386730
# legislation                             226488
# outcome_linked_to_object_of_search     1622210
# datetime                                     0
# removal_of_more_than_outer_clothing     777154
# outcome_object                               0
# location                                824862
# operation                              1719010
# officer_defined_ethnicity               391935
# type                                         0
# object_of_search                        407541
# force                                        0
# dtype: int64

# %%
data['age_range'].isna().values.any()
# Out:
# True

# %%
is_na = data.isnull()

row_has_na = is_na.sum(axis=1)>1

rows_with_na = data[row_has_na]
rows_with_na
# Out:
#         age_range                       outcome  involved_person  \
# 21          25-34                         False             True
# 28          18-24                         False             True
# 32            NaN                         False             True
# 33          18-24                         False             True
# 44          10-17              Local resolution             True
# ...           ...                           ...              ...
# 2893370     25-34                        Arrest             True
# 2893371     18-24     Summons / charged by post             True
# 2893374     25-34  A no further action disposal             True
# 2893377     18-24  A no further action disposal             True
# 2893383     10-17  A no further action disposal             True
#
#                                     self_defined_ethnicity gender  \
# 21                      White - Any other White background   Male
# ...

# %%
#data["operation"].notna().sum()
#is_na = data.isnull()

row_has_na = data['operation'].isna()

rows_with_na = data[row_has_na]
rows_with_na.head(100)
# Out:
#    age_range           outcome  involved_person  \
# 0      25-34             False             True
# 1      18-24             False             True
# 2      18-24             False             True
# 3      25-34             False             True
# 4      10-17             False             True
# ..       ...               ...              ...
# 95     25-34             False             True
# 96     25-34  Suspect arrested             True
# 97     25-34             False             True
# 98     25-34             False             True
# 99     25-34  Suspect arrested             True
#
#                                self_defined_ethnicity gender  \
# 0                  White - Any other White background   Male
# 1                     Asian/Asian British - Pakistani   Male
# 2                   Asian/Asian British - Bangladeshi   Male
# 3                     Other ethnic group - Not stated   Male
# 4   Black/African/Caribbean/Black British - Caribbean   Male
# ...

# %%
data = data.drop(["location"], axis=1)

# %%
data
# Out:
#         age_range                       outcome  involved_person  \
# 0           25-34                         False             True
# 1           18-24                         False             True
# 2           18-24                         False             True
# 3           25-34                         False             True
# 4           10-17                         False             True
# ...           ...                           ...              ...
# 2893380   over 34  A no further action disposal             True
# 2893381     25-34  A no further action disposal             True
# 2893382     25-34  A no further action disposal             True
# 2893383     10-17  A no further action disposal             True
# 2893384     18-24  A no further action disposal             True
#
#                                     self_defined_ethnicity gender  \
# 0                       White - Any other White background   Male
# ...

# %%
datetime = data["datetime"]

# %%
datetime = pd.DataFrame(datetime)

# %%
datetime = datetime["datetime"].tolist()

# %%
datetime = [i.split("T") for i in datetime]

# %%
date = [i[0] for i in datetime]
time = [i[1] for i in datetime]

# %%
time = [i.split(":") for i in time]
time = [i[0] for i in time]

# %%
time
# Out:
# ['11',
#  '00',
#  '00',
#  '08',
#  '08',
#  '08',
#  '08',
#  '08',
#  '09',
#  '14',
#  '16',
#  '16',
#  '00',
#  '12',
#  '13',
#  '16',
#  '13',
#  '21',
#  '21',
#  '22',
#  '00',
#  '11',
#  '22',
#  '22',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '11',
#  '11',
#  '11',
#  '03',
#  '15',
#  '15',
#  '15',
#  '16',
#  '16',
#  '18',
#  '23',
#  '23',
#  '04',
#  '04',
#  '05',
#  '17',
#  '18',
#  '19',
#  '23',
#  '23',
#  '23',
#  '20',
#  '17',
#  '23',
#  '17',
#  '21',
#  '09',
#  '15',
#  '15',
#  '11',
#  '13',
#  '18',
#  '19',
#  '19',
#  '06',
#  '06',
#  '06',
#  '22',
#  '22',
#  '22',
#  '22',
#  '23',
#  '09',
#  '10',
#  '10',
#  '04',
#  '04',
#  '10',
#  '19',
#  '23',
#  '23',
#  '23',
#  '11',
#  '00',
#  '14',
#  '14',
#  '07',
#  '07',
#  '07',
#  '07',
#  '09',
#  '09',
#  '12',
#  '17',
#  '17',
#  '17',
#  '11',
#  '15',
#  '17',
#  '17',
#  '20',
#  '23',
#  '23',
#  '23',
#  '03',
#  '14',
#  '15',
#  '15',
#  '15',
#  '14',
#  '20',
#  '20',
# ...

# %%
time = [int(i) for i in time]

# %%
time
# Out:
# [11,
#  0,
#  0,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  14,
#  16,
#  16,
#  0,
#  12,
#  13,
#  16,
#  13,
#  21,
#  21,
#  22,
#  0,
#  11,
#  22,
#  22,
#  3,
#  3,
#  3,
#  3,
#  3,
#  11,
#  11,
#  11,
#  3,
#  15,
#  15,
#  15,
#  16,
#  16,
#  18,
#  23,
#  23,
#  4,
#  4,
#  5,
#  17,
#  18,
#  19,
#  23,
#  23,
#  23,
#  20,
#  17,
#  23,
#  17,
#  21,
#  9,
#  15,
#  15,
#  11,
#  13,
#  18,
#  19,
#  19,
#  6,
#  6,
#  6,
#  22,
#  22,
#  22,
#  22,
#  23,
#  9,
#  10,
#  10,
#  4,
#  4,
#  10,
#  19,
#  23,
#  23,
#  23,
#  11,
#  0,
#  14,
#  14,
#  7,
#  7,
#  7,
#  7,
#  9,
#  9,
#  12,
#  17,
#  17,
#  17,
#  11,
#  15,
#  17,
#  17,
#  20,
#  23,
#  23,
#  23,
#  3,
#  14,
#  15,
#  15,
#  15,
#  14,
#  20,
#  20,
#  20,
#  20,
#  12,
#  3,
#  12,
#  2,
#  2,
#  2,
#  13,
#  14,
#  14,
#  17,
#  22,
#  12,
#  13,
#  13,
#  22,
#  22,
#  1,
#  3,
#  22,
#  22,
#  22,
#  22,
#  21,
#  0,
#  1,
#  1,
#  18,
#  19,
#  22,
#  3,
#  13,
#  14,
#  21,
#  22,
#  22,
#  22,
# ...

# %%
for i in range(len(time)):
    if time[i] > 0 and time[i] <= 6:
        time[i] = "early morning"
    elif time[i] > 6 and time[i] <= 12:
        time[i] = "morning"
    elif time[i] > 12 and time[i] <= 18:
        time[i] = "afternoon"
    else:
        time[i] = "evening"

# %%
time
# Out:
# ['morning',
#  'evening',
#  'evening',
#  'morning',
#  'morning',
#  'morning',
#  'morning',
#  'morning',
#  'morning',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'evening',
#  'morning',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'evening',
#  'evening',
#  'evening',
#  'evening',
#  'morning',
#  'evening',
#  'evening',
#  'early morning',
#  'early morning',
#  'early morning',
#  'early morning',
#  'early morning',
#  'morning',
#  'morning',
#  'morning',
#  'early morning',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'afternoon',
#  'evening',
#  'evening',
#  'early morning',
#  'early morning',
#  'early morning',
#  'afternoon',
#  'afternoon',
#  'evening',
#  'evening',
#  'evening',
#  'evening',
#  'evening',
#  'afternoon',
#  'evening',
#  'afternoon',
#  'evening',
#  'morning',
#  'afternoon',
#  'afternoon',
#  'morning',
#  'afternoon',
#  'afternoon',
#  'evening',
#  'evening',
#  'early morning',
# ...

# %%
data["time"] = time

# %%
date = [i.split("-") for i in date]

# %%
year = [i[0] for i in date]
month = [i[1] for i in date]
day = [i[2] for i in date]

# %%
day
# Out:
# ['10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '02',
#  '02',
#  '02',
#  '02',
#  '03',
#  '03',
#  '03',
#  '03',
#  '04',
#  '04',
#  '04',
#  '04',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '06',
#  '06',
#  '06',
#  '07',
#  '08',
#  '08',
#  '08',
#  '08',
#  '08',
#  '08',
#  '08',
#  '08',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '10',
#  '11',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '15',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '19',
#  '19',
#  '19',
#  '20',
#  '20',
#  '21',
#  '23',
#  '23',
#  '23',
#  '23',
#  '24',
#  '26',
#  '27',
#  '27',
#  '28',
#  '28',
#  '28',
#  '28',
#  '29',
#  '29',
#  '29',
#  '29',
#  '29',
#  '29',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '31',
#  '31',
#  '31',
#  '06',
#  '06',
#  '06',
#  '06',
#  '06',
#  '07',
#  '07',
#  '07',
# ...

# %%
data["date"], data["year"], data["month"], data["day"] = date, year, month, day

# %%
data = data.drop(["datetime", "date"], axis=1)

# %%
date = ["-".join(i) for i in date]

# %%
data["date"] = date

# %%
outcome = data["outcome_object"]

# %%
outcome = pd.DataFrame(outcome)

# %%
outcome = outcome["outcome_object"].tolist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-bf6de478179b> in <module>
# ----> 1 outcome = outcome["outcome_object"].tolist()
#
# TypeError: list indices must be integers or slices, not str

# %%
outcomes = [i.split(":") for i in outcome]

# %%
outcomes
# Out:
# [["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'nothing', 'name'", " 'Nothing found - No further action'}"],
#  ["{'id'", " 'local', 'name'", " 'Local resolution'}"],
#  ["{'id'", " 'arrest', 'name'", " 'Suspect arrested'}"],
# ...

# %%
out = [i[2].replace("}","").replace("\'","").strip() for i in outcomes]

# %%
data["outcome_object"] = out

# %%
data
# Out:
#         age_range                       outcome  involved_person  \
# 0           25-34                         False             True
# 1           18-24                         False             True
# 2           18-24                         False             True
# 3           25-34                         False             True
# 4           10-17                         False             True
# ...           ...                           ...              ...
# 2893380   over 34  A no further action disposal             True
# 2893381     25-34  A no further action disposal             True
# 2893382     25-34  A no further action disposal             True
# 2893383     10-17  A no further action disposal             True
# 2893384     18-24  A no further action disposal             True
#
#                                     self_defined_ethnicity gender  \
# 0                       White - Any other White background   Male
# ...

# %%
data.to_csv("stop_and_search_mostpopulatedcounties.csv")
